# %% [markdown]
# # Code for quicksort

# %%
#function to swap the two given indices of an array
def swap(arr, l, r):
    left_item = arr[l]
    right_item = arr[r]
    arr[l] = right_item
    arr[r] = left_item
    return arr

#This function returns the index of the pivot element, which will divide the array into two halves.
#arr = given array
#pivot = pivot element
#l = left cursor
#r = right cursor
def partition(arr):
    pivot = arr[0]
    l = 0
    r = len(arr)-1
    while(l<r):
        #increment l until an element greater than pivot is found
        while(arr[l]<=pivot and l<r):
            l = l+1
        #decrement right cursor until an element lower than pivot is found
        while(arr[r]>pivot and r>=l):
            r = r-1
        #if such elements are found
        if(l < r):
            arr = swap(arr, l ,r)        
    arr = swap(arr, 0, r) #since pivot = arr[0]
    pivot_index = r
    return arr, pivot_index


#quicksort function
def quicksort(arr):
    if(len(arr)==0 or len(arr)==1):
        return arr
    arr, pivot_index = partition(arr)
    first_arr = quicksort(arr[0:pivot_index])
    second_arr = quicksort(arr[pivot_index+1:])
    return first_arr+[arr[pivot_index]]+second_arr

# %% [markdown]
# # Code for testing

# %%
import random
import sys
import time
import numpy

#increasing recursion depth limit
print(sys.getrecursionlimit())
sys.setrecursionlimit(10000)
print(sys.getrecursionlimit())

runs=10
itr_for_one_run = 100
# itr_for_one_run = 10
#2d array for holding time taken
quicksort_total_time = []

for run in range(runs):
    quicksort_time_for_itr = []
    for i in range(1, itr_for_one_run+1):
        print("loop: ", i)
        # minimum range of random numbers
        lowerBound = 0
         
        # maximum range of random numbers
        upperBound = 10000
    
        #the size will keep on increasing by 100000 for each iteration
        size = 100000 * i
        array = [0]*size
        
        for j in range(size):
            array[j] = int(random.uniform(0, upperBound - lowerBound) + lowerBound)
        
        # print("Starting for ", array);
        start = time.process_time()
        quicksort(array)
        elapsed = time.process_time() - start
        quicksort_time_for_itr.append(round(elapsed, 5))
    # print(quicksort_time_for_itr)
    quicksort_total_time.append(quicksort_time_for_itr)
# print(quicksort_total_time)

TwoDArray = numpy.array(quicksort_total_time)
#averaging the runtime for each array length
total_time = numpy.sum(TwoDArray, axis = 0)/runs
print(total_time)
# Out:
# 3000
# 10000
# loop:  1
# loop:  2
# loop:  3
# loop:  4
# loop:  5
# loop:  6
# loop:  7
# loop:  8
# loop:  9
# loop:  10
# loop:  11
# loop:  12
# loop:  13
# loop:  14
# loop:  15
# loop:  16
# loop:  17
# loop:  18
# loop:  19
# loop:  20
# loop:  21
# loop:  22
# loop:  23
# loop:  24
# loop:  25
# loop:  26
# loop:  27
# loop:  28
# loop:  29
# loop:  30
# loop:  31
# loop:  32
# loop:  33
# loop:  34
# loop:  35
# loop:  36
# loop:  37
# loop:  38
# loop:  39
# loop:  40
# loop:  41
# loop:  42
# loop:  43
# loop:  44
# loop:  45
# loop:  46
# loop:  47
# loop:  48
# loop:  49
# loop:  50
# loop:  51
# loop:  52
# loop:  53
# loop:  54
# loop:  55
# loop:  56
# loop:  57
# loop:  58
# loop:  59
# loop:  60
# loop:  61
# loop:  62
# loop:  63
# loop:  64
# loop:  65
# loop:  66
# loop:  67
# loop:  68
# loop:  69
# loop:  70
# loop:  71
# loop:  72
# loop:  73
# loop:  74
# loop:  75
# loop:  76
# loop:  77
# loop:  78
# loop:  79
# loop:  80
# loop:  81
# loop:  82
# loop:  83
# loop:  84
# loop:  85
# loop:  86
# loop:  87
# loop:  88
# loop:  89
# loop:  90
# loop:  91
# loop:  92
# loop:  93
# loop:  94
# loop:  95
# loop:  96
# loop:  97
# loop:  98
# loop:  99
# loop:  100
# loop:  1
# loop:  2
# loop:  3
# loop:  4
# loop:  5
# loop:  6
# loop:  7
# loop:  8
# loop:  9
# loop:  10
# loop:  11
# loop:  12
# loop:  13
# loop:  14
# loop:  15
# loop:  16
# loop:  17
# loop:  18
# loop:  19
# loop:  20
# loop:  21
# loop:  22
# loop:  23
# loop:  24
# loop:  25
# loop:  26
# loop:  27
# loop:  28
# loop:  29
# loop:  30
# loop:  31
# loop:  32
# loop:  33
# loop:  34
# loop:  35
# loop:  36
# loop:  37
# loop:  38
# loop:  39
# loop:  40
# loop:  41
# loop:  42
# loop:  43
# loop:  44
# loop:  45
# loop:  46
# loop:  47
# loop:  48
# loop:  49
# loop:  50
# loop:  51
# loop:  52
# loop:  53
# loop:  54
# loop:  55
# loop:  56
# loop:  57
# loop:  58
# loop:  59
# loop:  60
# loop:  61
# loop:  62
# loop:  63
# loop:  64
# loop:  65
# loop:  66
# loop:  67
# loop:  68
# loop:  69
# loop:  70
# loop:  71
# loop:  72
# loop:  73
# loop:  74
# loop:  75
# loop:  76
# loop:  77
# loop:  78
# loop:  79
# loop:  80
# loop:  81
# loop:  82
# loop:  83
# loop:  84
# loop:  85
# loop:  86
# loop:  87
# loop:  88
# loop:  89
# loop:  90
# loop:  91
# loop:  92
# loop:  93
# loop:  94
# loop:  95
# loop:  96
# loop:  97
# loop:  98
# loop:  99
# loop:  100
# loop:  1
# loop:  2
# loop:  3
# loop:  4
# loop:  5
# loop:  6
# loop:  7
# loop:  8
# loop:  9
# loop:  10
# loop:  11
# loop:  12
# loop:  13
# loop:  14
# loop:  15
# loop:  16
# loop:  17
# loop:  18
# loop:  19
# loop:  20
# loop:  21
# loop:  22
# loop:  23
# loop:  24
# loop:  25
# loop:  26
# loop:  27
# loop:  28
# loop:  29
# loop:  30
# loop:  31
# loop:  32
# loop:  33
# loop:  34
# loop:  35
# loop:  36
# loop:  37
# loop:  38
# loop:  39
# loop:  40
# loop:  41
# loop:  42
# loop:  43
# loop:  44
# loop:  45
# loop:  46
# loop:  47
# loop:  48
# loop:  49
# loop:  50
# loop:  51
# loop:  52
# loop:  53
# loop:  54
# loop:  55
# loop:  56
# loop:  57
# loop:  58
# loop:  59
# loop:  60
# loop:  61
# loop:  62
# loop:  63
# loop:  64
# loop:  65
# loop:  66
# loop:  67
# loop:  68
# loop:  69
# loop:  70
# loop:  71
# loop:  72
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 36
#      34 # print("Starting for ", array);
#      35 start = time.process_time()
# ---> 36 quicksort(array)
#      37 elapsed = time.process_time() - start
#      38 quicksort_time_for_itr.append(round(elapsed, 5))
#
# Cell In[1], line 38, in quicksort(arr)
#      36     return arr
#      37 arr, pivot_index = partition(arr)
# ---> 38 first_arr = quicksort(arr[0:pivot_index])
#      39 second_arr = quicksort(arr[pivot_index+1:])
#      40 return first_arr+[arr[pivot_index]]+second_arr
#
# Cell In[1], line 38, in quicksort(arr)
#      36     return arr
#      37 arr, pivot_index = partition(arr)
# ---> 38 first_arr = quicksort(arr[0:pivot_index])
#      39 second_arr = quicksort(arr[pivot_index+1:])
#      40 return first_arr+[arr[pivot_index]]+second_arr
#
# Cell In[1], line 39, in quicksort(arr)
#      37 arr, pivot_index = partition(arr)
#      38 first_arr = quicksort(arr[0:pivot_index])
# ---> 39 second_arr = quicksort(arr[pivot_index+1:])
#      40 return first_arr+[arr[pivot_index]]+second_arr
#
# Cell In[1], line 38, in quicksort(arr)
#      36     return arr
#      37 arr, pivot_index = partition(arr)
# ---> 38 first_arr = quicksort(arr[0:pivot_index])
#      39 second_arr = quicksort(arr[pivot_index+1:])
#      40 return first_arr+[arr[pivot_index]]+second_arr
#
# Cell In[1], line 38, in quicksort(arr)
#      36     return arr
#      37 arr, pivot_index = partition(arr)
# ---> 38 first_arr = quicksort(arr[0:pivot_index])
#      39 second_arr = quicksort(arr[pivot_index+1:])
#      40 return first_arr+[arr[pivot_index]]+second_arr
#
#     [... skipping similar frames: quicksort at line 38 (7 times)]
#
# Cell In[1], line 38, in quicksort(arr)
#      36     return arr
#      37 arr, pivot_index = partition(arr)
# ---> 38 first_arr = quicksort(arr[0:pivot_index])
#      39 second_arr = quicksort(arr[pivot_index+1:])
#      40 return first_arr+[arr[pivot_index]]+second_arr
#
# Cell In[1], line 39, in quicksort(arr)
#      37 arr, pivot_index = partition(arr)
#      38 first_arr = quicksort(arr[0:pivot_index])
# ---> 39 second_arr = quicksort(arr[pivot_index+1:])
#      40 return first_arr+[arr[pivot_index]]+second_arr
#
# Cell In[1], line 39, in quicksort(arr)
#      37 arr, pivot_index = partition(arr)
#      38 first_arr = quicksort(arr[0:pivot_index])
# ---> 39 second_arr = quicksort(arr[pivot_index+1:])
#      40 return first_arr+[arr[pivot_index]]+second_arr
#
# Cell In[1], line 37, in quicksort(arr)
#      35 if(len(arr)==0 or len(arr)==1):
#      36     return arr
# ---> 37 arr, pivot_index = partition(arr)
#      38 first_arr = quicksort(arr[0:pivot_index])
#      39 second_arr = quicksort(arr[pivot_index+1:])
#
# Cell In[1], line 20, in partition(arr)
#      17 r = len(arr)-1
#      18 while(l<r):
#      19     #increment l until an element greater than pivot is found
# ---> 20     while(arr[l]<=pivot and l<r):
#      21         l = l+1
#      22     #decrement right cursor until an element lower than pivot is found
#
# KeyboardInterrupt:

# %%
#plotting the results
import matplotlib.pyplot as plt

size_axis = [100000 * i for i in range(1, itr_for_one_run+1)]
plt.plot(size_axis, total_time)
plt.plot(size_axis, total_time, 'or')
plt.show()
